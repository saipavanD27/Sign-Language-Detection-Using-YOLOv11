# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.8/974.8 kB 26.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 66.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 35.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 47.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 95.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from ultralytics import YOLO
from IPython.display import Image
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
import gdown
# download the data from g drive

url = ""#Download sign language yolo data from roboflow.ai and place it in goolge drive and share it using url, paste it here
file_id = url.split("/")[-2]
print(file_id)

prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "sign_data.zip")
# Out:
# 1Zf8RWe9m7CzgeNTJ0NWWTnlliPnXJin1
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1Zf8RWe9m7CzgeNTJ0NWWTnlliPnXJin1
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1Zf8RWe9m7CzgeNTJ0NWWTnlliPnXJin1&confirm=t&uuid=d08ad30d-2f91-4bba-be6b-61a4f662e055
# To: /content/sign_data.zip
# 100%|██████████| 31.4M/31.4M [00:00<00:00, 122MB/s]
# 'sign_data.zip'

# %%
# !unzip sign_data.zip
# Out:
# Archive:  sign_data.zip
#    creating: test/
#    creating: test/images/
#   inflating: test/images/A22_jpg.rf.f02ad8558ce1c88213b4f83c0bc66bc8.jpg
#   inflating: test/images/B14_jpg.rf.ed5ba6d44f55ab03e62d2baeac4aa1aa.jpg
#   inflating: test/images/B15_jpg.rf.0f0628552139144fc67c453e1f1b7b15.jpg
#   inflating: test/images/B19_jpg.rf.69527cc1f34d694cc04e55db80ed9b1a.jpg
#   inflating: test/images/C17_jpg.rf.ceb81f8ae3c3673bd060ebe71848eca8.jpg
#   inflating: test/images/C19_jpg.rf.577ce02a223c65e89dc4a4eacd130040.jpg
#   inflating: test/images/C22_jpg.rf.e54cbbfdd4ea0670eb4e1c507de4a8a2.jpg
#   inflating: test/images/C23_jpg.rf.cff2647e71600ac354da45cb87eca667.jpg
#   inflating: test/images/D1_jpg.rf.89a5f6f41bf8bc795db94105f709dd34.jpg
#   inflating: test/images/F17_jpg.rf.6097db79e0385af55b85ad5fa03cdc55.jpg
#   inflating: test/images/F3_jpg.rf.c854e14a7108c9294c226a392026e73b.jpg
#   inflating: test/images/G11_jpg.rf.cc02dc447a7959e73869f4f45b0ef29a.jpg
# ...

# %%
# !yolo task=detect mode=train data="/content/data.yaml" model="yolo11l.pt" epochs=30 imgsz=640
# Out:
# ...
# 100% 49.0M/49.0M [00:00<00:00, 399MB/s]
# Ultralytics 8.3.103 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')  # Mount Google Drive

# Copy best.pt to Drive
# !cp /content/runs/detect/train/weights/best.pt /content/drive/MyDrive/best.pt
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Your model will now be saved in Google Drive → My Drive.
# Next time, just copy it back to Colab:
# !cp /content/drive/MyDrive/best.pt /content/runs/detect/train2/weights/

# %% [markdown]
# ✅ 3. Load the Saved Model in Future Sessions
# Instead of retraining, simply load the saved model:
# import torch
# model = torch.hub.load('ultralytics/yolov5', 'custom', path='/content/runs/detect/train2/weights/best.pt')

# %%
from google.colab import files
files.download('/content/runs/detect/train/weights/best.pt')

# %%
Image("/content/runs/detect/train/confusion_matrix.png", width=500)

# %%
Image("/content/runs/detect/train/labels.jpg", width=500)

# %%
Image("/content/runs/detect/train/results.png", width=600)

# %%
Image("/content/runs/detect/train/train_batch0.jpg", width=600)

# %%
Image("/content/runs/detect/train/val_batch0_pred.jpg", width=600)

# %%
# !yolo task=detect mode=predict model="/content/runs/detect/train/weights/best.pt" conf=0.5 source="/content/test/images" save=True
# Out:
# Ultralytics 8.3.103 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11l summary (fused): 190 layers, 25,303,984 parameters, 0 gradients, 86.7 GFLOPs
#
# image 1/72 /content/test/images/A22_jpg.rf.f02ad8558ce1c88213b4f83c0bc66bc8.jpg: 640x640 1 A, 47.5ms
# image 2/72 /content/test/images/B14_jpg.rf.ed5ba6d44f55ab03e62d2baeac4aa1aa.jpg: 640x640 1 B, 47.6ms
# image 3/72 /content/test/images/B15_jpg.rf.0f0628552139144fc67c453e1f1b7b15.jpg: 640x640 1 B, 47.5ms
# image 4/72 /content/test/images/B19_jpg.rf.69527cc1f34d694cc04e55db80ed9b1a.jpg: 640x640 1 B, 47.5ms
# image 5/72 /content/test/images/C17_jpg.rf.ceb81f8ae3c3673bd060ebe71848eca8.jpg: 640x640 1 C, 47.5ms
# image 6/72 /content/test/images/C19_jpg.rf.577ce02a223c65e89dc4a4eacd130040.jpg: 640x640 1 F, 47.5ms
# image 7/72 /content/test/images/C22_jpg.rf.e54cbbfdd4ea0670eb4e1c507de4a8a2.jpg: 640x640 1 C, 29.5ms
# image 8/72 /content/test/images/C23_jpg.rf.cff2647e71600ac354da45cb87eca667.jpg: 640x640 1 C, 25.8ms
# ...

# %%
import glob
import os
from IPython.display import Image as IPyImage, display

latest_folder = max(glob.glob('/content/runs/detect/predict*/'), key=os.path.getmtime)
for img in glob.glob(f'{latest_folder}/*.jpg')[1:11]:
    display(IPyImage(filename=img, width=600))
    print("\n")

# %%
# !pip install ultralytics opencv-python numpy

# %%
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode
import cv2
import numpy as np
import PIL
import io

def take_photo(filename='photo.jpg', quality=0.8):
    js = Javascript('''
        async function takePhoto(quality) {
            const div = document.createElement('div');
            document.body.appendChild(div);
            const video = document.createElement('video');
            const stream = await navigator.mediaDevices.getUserMedia({video: true});

            document.body.appendChild(video);
            video.srcObject = stream;
            await new Promise((resolve) => video.onloadedmetadata = resolve);
            video.play();

            await new Promise((resolve) => setTimeout(resolve, 7000));  // Wait for 7 seconds

            const canvas = document.createElement('canvas');
            canvas.width = video.videoWidth;
            canvas.height = video.videoHeight;
            const ctx = canvas.getContext('2d');
            ctx.drawImage(video, 0, 0, canvas.width, canvas.height);

            stream.getTracks().forEach(track => track.stop());
            div.remove();

            return canvas.toDataURL('image/jpeg', quality);
        }
    ''')

    display(js)
    data = eval_js('takePhoto({})'.format(quality))
    binary = b64decode(data.split(',')[1])
    with open(filename, 'wb') as f:
        f.write(binary)

    return filename

# Capture Image
image_path = take_photo()
print(f"Image saved as: {image_path}")
# Out:
# Image saved as: photo.jpg

# %%
from IPython.display import display
from PIL import Image as PILImage  # Rename PIL Image to avoid conflict

# Open and display the captured image

image_path = "photo.jpg"
image = PILImage.open(image_path)
display(image)

# %%
import torch
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
from IPython.display import Image # Import the Image class

# Load trained YOLO model
#/content/best (1).pt
#/content/runs/detect/train/weights/best.pt
model_path = "/content/runs/detect/train/weights/best.pt"  # Adjust the path if needed
model = YOLO(model_path)

# Read captured image
image_path = "photo.jpg"
image = cv2.imread(image_path)

# Run YOLO prediction
results = model(image, conf=0.25)

# Plot results
for result in results:
    result.show()  # Display results

# Save results
results[0].save(filename="detected.jpg")
print("Detection saved as detected.jpg")

# Show detected image
display(Image("detected.jpg")) # Now Image is defined and should work
